# %%
import pandas as pd
import json
from utils import *
from agglo import *
from datetime import datetime
import matplotlib
import matplotlib.pyplot as plt

# %%
f = open('collected_data.json')
data = json.load(f)
movie_names = []
for x in data.keys():
    movie_names.append(x)
    
movie_names.sort(key=lambda x:x[0])
#movie_names

# %%
def get_average(s,reviews):
    movie = reviews[s]
    comments = movie["Comments"]
    date_ratings = []
    for comment in comments:
        date = comment["Date"]
        format_of_date = "%d %B %Y"
        new_date = datetime.strptime(date,format_of_date)
        x = []
        x.append(new_date)
        x.append(comment["Rating"])
        date_ratings.append(x)
    date_ratings.sort(key=lambda x:x[0])
    date_ratings_moving_avg = []
    total_rating = 0
    count_rating = 0;
    for comment in date_ratings:
        total_rating = total_rating + comment[1]
        count_rating = count_rating + 1
        average = total_rating/count_rating
        x = []
        x.append(comment[0])
        x.append(average)
        date_ratings_moving_avg.append(x)
    return date_ratings_moving_avg

# %%
def get_moving_average(s,reviews):
    movie = reviews[s]
    comments = movie["Comments"]
    date_ratings = []
    for comment in comments:
        date = comment["Date"]
        format_of_date = "%d %B %Y"
        new_date = datetime.strptime(date,format_of_date)
        x = []
        x.append(new_date)
        x.append(comment["Rating"])
        date_ratings.append(x)
    date_ratings.sort(key=lambda x:x[0])
    date_ratings_moving_avg = []
    average_till_now = 0
    alpha = 0.05
    for comment in date_ratings:
        if len(date_ratings_moving_avg)==0:
            date_ratings_moving_avg.append(comment)
            average_till_now = comment[1]
        else:
            average_till_now = alpha*comment[1] + (1-alpha)*average_till_now
            x = []
            x.append(comment[0])
            x.append(average_till_now)
            date_ratings_moving_avg.append(x)
    return date_ratings_moving_avg

# %%
def graph_of_data(data,title):
    x = []
    y = []
    for d in data:
        x.append(d[0])
        y.append(d[1])
    plt.rcParams.update({'font.size': 22})
    plt.figure(figsize=(16,9))
    plt.plot(x,y)
    plt.xlabel('Date')
    plt.ylabel('Rating')
    plt.title(title)
    plt.savefig(title,transparent=False)

# %%
plot_data = get_moving_average("Mission: Impossible II",data)
graph_of_data(plot_data,'Mission: Impossible II IMDB')

# %%
plot_data
# Out:
# [[datetime.datetime(1998, 9, 4, 0, 0), 1],
#  [datetime.datetime(1998, 9, 4, 0, 0), 1.0],
#  [datetime.datetime(1998, 9, 12, 0, 0), 1.0],
#  [datetime.datetime(1998, 9, 20, 0, 0), 1.45],
#  [datetime.datetime(1998, 9, 20, 0, 0), 1.4275],
#  [datetime.datetime(1998, 9, 24, 0, 0), 1.406125],
#  [datetime.datetime(1998, 9, 25, 0, 0), 1.38581875],
#  [datetime.datetime(1998, 9, 28, 0, 0), 1.8165278125],
#  [datetime.datetime(1998, 10, 1, 0, 0), 1.775701421875],
#  [datetime.datetime(1998, 11, 5, 0, 0), 1.73691635078125],
#  [datetime.datetime(1998, 11, 5, 0, 0), 1.7000705332421875],
#  [datetime.datetime(1998, 11, 6, 0, 0), 1.6650670065800781],
#  [datetime.datetime(1998, 11, 8, 0, 0), 2.031813656251074],
#  [datetime.datetime(1998, 11, 9, 0, 0), 2.43022297343852],
#  [datetime.datetime(1998, 11, 9, 0, 0), 2.708711824766594],
#  [datetime.datetime(1998, 11, 13, 0, 0), 2.9232762335282643],
#  [datetime.datetime(1998, 11, 18, 0, 0), 2.827112421851851],
#  [datetime.datetime(1998, 11, 23, 0, 0), 3.085756800759258],
#  [datetime.datetime(1998, 12, 2, 0, 0), 3.4314689607212947],
#  [datetime.datetime(1998, 12, 11, 0, 0), 3.75989551268523],
#  [datetime.datetime(1999, 1, 1, 0, 0), 4.071900737050969],
#  [datetime.datetime(1999, 1, 1, 0, 0), 3.9183057001984203],
#  [datetime.datetime(1999, 1, 23, 0, 0), 3.822390415188499],
#  [datetime.datetime(1999, 2, 13, 0, 0), 3.681270894429074],
#  [datetime.datetime(1999, 3, 1, 0, 0), 3.54720734970762],
#  [datetime.datetime(1999, 3, 23, 0, 0), 3.469846982222239],
#  [datetime.datetime(1999, 4, 15, 0, 0), 3.346354633111127],
#  [datetime.datetime(1999, 4, 18, 0, 0), 3.2290369014555704],
#  [datetime.datetime(1999, 5, 4, 0, 0), 3.1175850563827914],
#  [datetime.datetime(1999, 5, 12, 0, 0), 3.111705803563652],
#  [datetime.datetime(1999, 6, 15, 0, 0), 3.006120513385469],
#  [datetime.datetime(1999, 6, 17, 0, 0), 2.9558144877161956],
#  [datetime.datetime(1999, 6, 24, 0, 0), 2.8580237633303853],
#  [datetime.datetime(1999, 6, 26, 0, 0), 2.7651225751638657],
#  [datetime.datetime(1999, 7, 11, 0, 0), 2.676866446405672],
#  [datetime.datetime(1999, 7, 22, 0, 0), 2.5930231240853883],
#  [datetime.datetime(1999, 7, 25, 0, 0), 2.5133719678811186],
#  [datetime.datetime(1999, 7, 27, 0, 0), 2.8377033694870626],
#  [datetime.datetime(1999, 7, 29, 0, 0), 2.9958182010127095],
#  [datetime.datetime(1999, 8, 12, 0, 0), 2.8960272909620737],
#  [datetime.datetime(1999, 9, 6, 0, 0), 3.25122592641397],
#  [datetime.datetime(1999, 9, 19, 0, 0), 3.138664630093271],
#  [datetime.datetime(1999, 10, 22, 0, 0), 3.0317313985886067],
#  [datetime.datetime(1999, 10, 31, 0, 0), 3.3801448286591764],
#  [datetime.datetime(1999, 11, 5, 0, 0), 3.261137587226217],
#  [datetime.datetime(1999, 11, 22, 0, 0), 3.148080707864906],
#  [datetime.datetime(2000, 1, 21, 0, 0), 3.0406766724716605],
#  [datetime.datetime(2000, 1, 27, 0, 0), 2.938642838848077],
#  [datetime.datetime(2000, 2, 2, 0, 0), 3.041710696905673],
#  [datetime.datetime(2000, 2, 2, 0, 0), 2.939625162060389],
#  [datetime.datetime(2000, 2, 20, 0, 0), 2.9926439039573696],
#  [datetime.datetime(2000, 2, 23, 0, 0), 2.893011708759501],
#  [datetime.datetime(2000, 4, 7, 0, 0), 2.7983611233215253],
#  [datetime.datetime(2000, 6, 27, 0, 0), 2.858443067155449],
#  [datetime.datetime(2000, 8, 20, 0, 0), 3.2155209137976764],
#  [datetime.datetime(2000, 9, 12, 0, 0), 3.1547448681077923],
#  [datetime.datetime(2000, 10, 23, 0, 0), 3.0470076247024025],
#  [datetime.datetime(2000, 12, 1, 0, 0), 2.944657243467282],
#  [datetime.datetime(2001, 2, 11, 0, 0), 2.897424381293918],
#  [datetime.datetime(2001, 3, 4, 0, 0), 2.802553162229222],
#  [datetime.datetime(2001, 4, 17, 0, 0), 3.1624255041177607],
#  [datetime.datetime(2001, 5, 26, 0, 0), 3.1543042289118723],
#  [datetime.datetime(2001, 5, 28, 0, 0), 3.0965890174662785],
#  [datetime.datetime(2001, 11, 20, 0, 0), 3.0417595665929644],
#  [datetime.datetime(2002, 2, 10, 0, 0), 2.939671588263316],
#  [datetime.datetime(2002, 3, 18, 0, 0), 3.29268800885015],
#  [datetime.datetime(2002, 3, 26, 0, 0), 3.5280536084076424],
#  [datetime.datetime(2002, 4, 10, 0, 0), 3.7016509279872603],
#  [datetime.datetime(2002, 4, 13, 0, 0), 3.766568381587897],
#  [datetime.datetime(2002, 4, 15, 0, 0), 3.878239962508502],
#  [datetime.datetime(2002, 5, 4, 0, 0), 4.134327964383076],
#  [datetime.datetime(2002, 5, 10, 0, 0), 4.077611566163922],
#  [datetime.datetime(2002, 6, 9, 0, 0), 3.9237309878557256],
#  [datetime.datetime(2002, 10, 18, 0, 0), 3.777544438462939],
#  [datetime.datetime(2002, 10, 29, 0, 0), 3.6386672165397917],
#  [datetime.datetime(2002, 12, 16, 0, 0), 3.5067338557128016],
#  [datetime.datetime(2002, 12, 19, 0, 0), 3.8313971629271615],
#  [datetime.datetime(2003, 2, 22, 0, 0), 3.689827304780803],
#  [datetime.datetime(2003, 7, 22, 0, 0), 4.005335939541762],
#  [datetime.datetime(2003, 8, 3, 0, 0), 4.305069142564674],
#  [datetime.datetime(2003, 9, 18, 0, 0), 4.489815685436441],
#  [datetime.datetime(2003, 10, 20, 0, 0), 4.715324901164619],
#  [datetime.datetime(2003, 11, 1, 0, 0), 4.779558656106388],
#  [datetime.datetime(2003, 11, 4, 0, 0), 4.690580723301069],
#  [datetime.datetime(2004, 2, 5, 0, 0), 4.6060516871360155],
#  [datetime.datetime(2004, 3, 20, 0, 0), 4.425749102779214],
#  [datetime.datetime(2004, 4, 13, 0, 0), 4.2544616476402535],
#  [datetime.datetime(2004, 4, 22, 0, 0), 4.291738565258241],
#  [datetime.datetime(2004, 5, 7, 0, 0), 4.327151636995328],
#  [datetime.datetime(2004, 5, 15, 0, 0), 4.210794055145561],
#  [datetime.datetime(2004, 7, 11, 0, 0), 4.050254352388283],
#  [datetime.datetime(2004, 7, 28, 0, 0), 3.8977416347688685],
#  [datetime.datetime(2005, 1, 3, 0, 0), 3.7528545530304247],
#  [datetime.datetime(2005, 1, 6, 0, 0), 3.965211825378903],
#  [datetime.datetime(2005, 1, 7, 0, 0), 3.8169512341099576],
#  [datetime.datetime(2005, 2, 9, 0, 0), 4.12610367240446],
#  [datetime.datetime(2005, 2, 9, 0, 0), 4.419798488784236],
#  [datetime.datetime(2005, 3, 8, 0, 0), 4.648808564345025],
#  [datetime.datetime(2005, 3, 13, 0, 0), 4.466368136127773],
#  [datetime.datetime(2005, 6, 18, 0, 0), 4.493049729321385],
#  [datetime.datetime(2005, 7, 16, 0, 0), 4.3183972428553155],
#  [datetime.datetime(2005, 7, 16, 0, 0), 4.15247738071255],
#  [datetime.datetime(2005, 7, 20, 0, 0), 4.194853511676921],
#  [datetime.datetime(2005, 7, 26, 0, 0), 4.035110836093075],
#  [datetime.datetime(2005, 9, 3, 0, 0), 3.883355294288421],
#  [datetime.datetime(2005, 10, 12, 0, 0), 3.789187529574],
#  [datetime.datetime(2006, 1, 14, 0, 0), 3.6997281530953],
#  [datetime.datetime(2006, 1, 27, 0, 0), 3.9147417454405344],
#  [datetime.datetime(2006, 3, 1, 0, 0), 4.019004658168508],
#  [datetime.datetime(2006, 3, 11, 0, 0), 4.118054425260082],
#  [datetime.datetime(2006, 4, 2, 0, 0), 4.012151703997078],
#  [datetime.datetime(2006, 4, 3, 0, 0), 4.061544118797224],
#  [datetime.datetime(2006, 4, 14, 0, 0), 4.308466912857362],
#  [datetime.datetime(2006, 4, 21, 0, 0), 4.393043567214494],
#  [datetime.datetime(2006, 4, 25, 0, 0), 4.273391388853768],
#  [datetime.datetime(2006, 4, 29, 0, 0), 4.509721819411079],
#  [datetime.datetime(2006, 5, 30, 0, 0), 4.334235728440525],
#  [datetime.datetime(2006, 5, 31, 0, 0), 4.417523942018499],
#  [datetime.datetime(2006, 6, 24, 0, 0), 4.646647744917574],
#  [datetime.datetime(2006, 6, 24, 0, 0), 4.464315357671695],
#  [datetime.datetime(2006, 7, 9, 0, 0), 4.29109958978811],
#  [datetime.datetime(2006, 8, 25, 0, 0), 4.126544610298704],
#  [datetime.datetime(2006, 10, 16, 0, 0), 3.9702173797837683],
#  [datetime.datetime(2006, 11, 4, 0, 0), 3.8217065107945793],
#  [datetime.datetime(2007, 1, 8, 0, 0), 3.93062118525485],
#  [datetime.datetime(2007, 2, 12, 0, 0), 3.7840901259921074],
#  [datetime.datetime(2007, 3, 22, 0, 0), 3.9948856196925018],
#  [datetime.datetime(2007, 3, 30, 0, 0), 3.8451413387078763],
#  [datetime.datetime(2007, 4, 27, 0, 0), 3.9028842717724825],
#  [datetime.datetime(2007, 4, 29, 0, 0), 3.9077400581838586],
#  [datetime.datetime(2007, 6, 3, 0, 0), 3.7623530552746653],
#  [datetime.datetime(2007, 6, 12, 0, 0), 3.774235402510932],
#  [datetime.datetime(2007, 7, 14, 0, 0), 4.085523632385385],
#  [datetime.datetime(2007, 8, 21, 0, 0), 4.281247450766116],
#  [datetime.datetime(2007, 9, 9, 0, 0), 4.417185078227809],
#  [datetime.datetime(2007, 11, 27, 0, 0), 4.646325824316419],
#  [datetime.datetime(2008, 1, 25, 0, 0), 4.9140095331005975],
#  [datetime.datetime(2008, 2, 24, 0, 0), 4.718309056445567],
#  [datetime.datetime(2008, 2, 24, 0, 0), 4.982393603623288],
#  [datetime.datetime(2008, 3, 4, 0, 0), 4.983273923442123],
#  [datetime.datetime(2008, 4, 29, 0, 0), 5.234110227270017],
#  [datetime.datetime(2008, 5, 30, 0, 0), 5.472404715906516],
#  [datetime.datetime(2008, 6, 8, 0, 0), 5.598784480111191],
#  [datetime.datetime(2008, 8, 10, 0, 0), 5.618845256105631],
#  [datetime.datetime(2008, 11, 23, 0, 0), 5.587902993300349],
#  [datetime.datetime(2008, 12, 30, 0, 0), 5.608507843635332],
#  [datetime.datetime(2009, 3, 17, 0, 0), 5.378082451453564],
#  [datetime.datetime(2009, 3, 20, 0, 0), 5.409178328880886],
#  [datetime.datetime(2009, 4, 10, 0, 0), 5.238719412436841],
#  [datetime.datetime(2009, 6, 11, 0, 0), 5.476783441814998],
#  [datetime.datetime(2009, 6, 21, 0, 0), 5.352944269724248],
#  [datetime.datetime(2009, 9, 19, 0, 0), 5.185297056238035],
#  [datetime.datetime(2010, 4, 5, 0, 0), 5.126032203426133],
#  [datetime.datetime(2010, 4, 6, 0, 0), 5.169730593254826],
#  [datetime.datetime(2010, 5, 15, 0, 0), 4.961244063592084],
#  [datetime.datetime(2011, 1, 10, 0, 0), 5.013181860412479],
#  [datetime.datetime(2011, 3, 21, 0, 0), 4.812522767391855],
#  [datetime.datetime(2011, 6, 16, 0, 0), 4.721896629022263],
#  [datetime.datetime(2011, 8, 29, 0, 0), 4.835801797571149],
#  [datetime.datetime(2012, 3, 3, 0, 0), 4.894011707692591],
#  [datetime.datetime(2012, 4, 1, 0, 0), 4.699311122307961],
#  [datetime.datetime(2012, 8, 7, 0, 0), 4.764345566192563],
#  [datetime.datetime(2012, 9, 23, 0, 0), 4.776128287882934],
#  [datetime.datetime(2012, 10, 9, 0, 0), 4.637321873488787],
#  [datetime.datetime(2013, 1, 3, 0, 0), 4.705455779814347],
#  [datetime.datetime(2013, 3, 1, 0, 0), 4.72018299082363],
#  [datetime.datetime(2013, 3, 9, 0, 0), 4.834173841282448],
#  [datetime.datetime(2013, 4, 22, 0, 0), 4.742465149218326],
#  [datetime.datetime(2013, 4, 30, 0, 0), 4.8053418917574096],
#  [datetime.datetime(2013, 5, 5, 0, 0), 4.615074797169538],
#  [datetime.datetime(2013, 5, 23, 0, 0), 4.434321057311061],
#  [datetime.datetime(2013, 6, 3, 0, 0), 4.712605004445508],
#  [datetime.datetime(2013, 8, 6, 0, 0), 4.9769747542232325],
#  [datetime.datetime(2013, 8, 12, 0, 0), 5.128126016512071],
#  [datetime.datetime(2013, 9, 15, 0, 0), 4.921719715686467],
#  [datetime.datetime(2013, 10, 6, 0, 0), 5.075633729902144],
#  [datetime.datetime(2013, 10, 7, 0, 0), 5.121852043407037],
#  [datetime.datetime(2013, 10, 8, 0, 0), 4.915759441236684],
#  [datetime.datetime(2013, 11, 26, 0, 0), 5.11997146917485],
#  [datetime.datetime(2014, 3, 4, 0, 0), 5.263972895716107],
#  [datetime.datetime(2014, 4, 28, 0, 0), 5.350774250930302],
#  [datetime.datetime(2014, 5, 12, 0, 0), 5.383235538383786],
#  [datetime.datetime(2014, 5, 16, 0, 0), 5.214073761464596],
#  [datetime.datetime(2014, 5, 17, 0, 0), 5.353370073391367],
#  [datetime.datetime(2014, 5, 18, 0, 0), 5.435701569721798],
#  [datetime.datetime(2014, 5, 21, 0, 0), 5.663916491235708],
#  [datetime.datetime(2014, 5, 22, 0, 0), 5.780720666673922],
#  [datetime.datetime(2014, 5, 24, 0, 0), 5.741684633340226],
#  [datetime.datetime(2014, 5, 27, 0, 0), 5.704600401673214],
#  [datetime.datetime(2014, 6, 2, 0, 0), 5.769370381589552],
#  [datetime.datetime(2014, 6, 5, 0, 0), 5.530901862510074],
#  [datetime.datetime(2014, 8, 14, 0, 0), 5.3543567693845695],
#  [datetime.datetime(2014, 10, 11, 0, 0), 5.386638930915341],
#  [datetime.datetime(2015, 3, 29, 0, 0), 5.417306984369573],
#  [datetime.datetime(2015, 4, 26, 0, 0), 5.596441635151095],
#  [datetime.datetime(2015, 6, 16, 0, 0), 5.41661955339354],
#  [datetime.datetime(2015, 8, 8, 0, 0), 5.2457885757238625],
#  [datetime.datetime(2015, 9, 11, 0, 0), 5.083499146937669],
#  [datetime.datetime(2015, 11, 19, 0, 0), 4.929324189590785],
#  [datetime.datetime(2016, 3, 13, 0, 0), 5.082857980111246],
#  [datetime.datetime(2016, 7, 22, 0, 0), 4.878715081105684],
#  [datetime.datetime(2016, 8, 30, 0, 0), 4.934779327050399],
#  [datetime.datetime(2016, 8, 30, 0, 0), 5.038040360697878],
#  [datetime.datetime(2016, 9, 10, 0, 0), 4.836138342662984],
#  [datetime.datetime(2017, 1, 23, 0, 0), 4.9443314255298345],
#  [datetime.datetime(2017, 1, 31, 0, 0), 5.097114854253343],
#  [datetime.datetime(2017, 8, 2, 0, 0), 5.292259111540676],
#  [datetime.datetime(2018, 1, 28, 0, 0), 5.3776461559636415],
#  [datetime.datetime(2018, 5, 31, 0, 0), 5.50876384816546],
#  [datetime.datetime(2018, 6, 22, 0, 0), 5.533325655757186],
#  [datetime.datetime(2018, 7, 5, 0, 0), 5.306659372969326],
#  [datetime.datetime(2018, 8, 11, 0, 0), 5.4413264043208605],
#  [datetime.datetime(2018, 9, 1, 0, 0), 5.669260084104817],
#  [datetime.datetime(2018, 12, 8, 0, 0), 5.485797079899576],
#  [datetime.datetime(2018, 12, 11, 0, 0), 5.7115072259045965],
#  [datetime.datetime(2019, 2, 10, 0, 0), 5.725931864609366],
#  [datetime.datetime(2019, 3, 11, 0, 0), 5.639635271378898],
#  [datetime.datetime(2019, 5, 29, 0, 0), 5.5076535078099536],
#  [datetime.datetime(2019, 6, 24, 0, 0), 5.582270832419455],
#  [datetime.datetime(2019, 7, 13, 0, 0), 5.353157290798483],
#  [datetime.datetime(2019, 7, 19, 0, 0), 5.185499426258557],
#  [datetime.datetime(2019, 7, 21, 0, 0), 5.026224454945629],
#  [datetime.datetime(2019, 8, 15, 0, 0), 5.274913232198347],
#  [datetime.datetime(2019, 9, 9, 0, 0), 5.06116757058843],
#  [datetime.datetime(2019, 10, 22, 0, 0), 4.908109192059008],
#  [datetime.datetime(2019, 10, 25, 0, 0), 4.712703732456058],
#  [datetime.datetime(2019, 10, 28, 0, 0), 4.527068545833255],
#  [datetime.datetime(2019, 11, 6, 0, 0), 4.350715118541592],
#  [datetime.datetime(2019, 12, 7, 0, 0), 4.283179362614512],
#  [datetime.datetime(2019, 12, 29, 0, 0), 4.119020394483786],
#  [datetime.datetime(2020, 1, 6, 0, 0), 4.163069374759596],
#  [datetime.datetime(2020, 2, 9, 0, 0), 4.004915906021616],
#  [datetime.datetime(2020, 2, 17, 0, 0), 4.1046701107205354],
#  [datetime.datetime(2020, 3, 18, 0, 0), 4.049436605184509],
#  [datetime.datetime(2020, 3, 21, 0, 0), 4.196964774925283],
#  [datetime.datetime(2020, 5, 10, 0, 0), 4.287116536179019],
#  [datetime.datetime(2020, 5, 18, 0, 0), 4.322760709370067],
#  [datetime.datetime(2020, 5, 24, 0, 0), 4.456622673901563],
#  [datetime.datetime(2020, 5, 29, 0, 0), 4.633791540206485],
#  [datetime.datetime(2020, 6, 5, 0, 0), 4.702101963196161],
#  [datetime.datetime(2020, 6, 5, 0, 0), 4.516996865036353],
#  [datetime.datetime(2020, 7, 12, 0, 0), 4.491147021784535],
#  [datetime.datetime(2020, 8, 15, 0, 0), 4.366589670695308],
#  [datetime.datetime(2020, 8, 30, 0, 0), 4.398260187160542],
#  [datetime.datetime(2020, 9, 17, 0, 0), 4.4283471778025145],
#  [datetime.datetime(2020, 10, 26, 0, 0), 4.606929818912389],
#  [datetime.datetime(2020, 12, 7, 0, 0), 4.726583327966769],
#  [datetime.datetime(2020, 12, 26, 0, 0), 4.640254161568431],
#  [datetime.datetime(2021, 2, 22, 0, 0), 4.708241453490009],
#  [datetime.datetime(2021, 3, 15, 0, 0), 4.872829380815509],
#  [datetime.datetime(2021, 3, 27, 0, 0), 4.7291879117747335],
#  [datetime.datetime(2021, 4, 3, 0, 0), 4.842728516185996],
#  [datetime.datetime(2021, 4, 21, 0, 0), 4.800592090376696],
#  [datetime.datetime(2021, 5, 20, 0, 0), 5.0605624858578615],
#  [datetime.datetime(2021, 6, 11, 0, 0), 5.157534361564968],
#  [datetime.datetime(2021, 8, 9, 0, 0), 5.199657643486719],
#  [datetime.datetime(2021, 8, 22, 0, 0), 5.289674761312383]]
